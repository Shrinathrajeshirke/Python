# %% [markdown]
# ### Named Entity Recognition
#
# Named Entity Recognition (NER) in NLP focuses on identifying and categorizing important information known as entities in text. These entities can be names of people, places, organizations, dates, etc.

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Shrinath\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Shrinath\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
content = "Trinamool Congress leader Mahua Moitra has moved the Supreme Court against her expulsion from the Lok Sabha over the cash-for-query allegations against her. Moitra was ousted from the Parliament last week after the Ethics Committee of the Lok Sabha found her guilty of jeopardising national security by sharing her parliamentary portal's login credentials with businessman Darshan Hiranandani."

import nltk

## tokenizing to words
words = nltk.word_tokenize(content)

## pos tag elements
pos_tag = nltk.pos_tag(words)

## named entity recognition
print(nltk.ne_chunk(pos_tag))

nltk.ne_chunk(pos_tag).draw()
# Out:
# (S
#   (PERSON Trinamool/NNP)
#   (ORGANIZATION Congress/NNP)
#   leader/NN
#   (PERSON Mahua/NNP Moitra/NNP)
#   has/VBZ
#   moved/VBN
#   the/DT
#   (ORGANIZATION Supreme/NNP Court/NNP)
#   against/IN
#   her/PRP$
#   expulsion/NN
#   from/IN
#   the/DT
#   (ORGANIZATION Lok/NNP Sabha/NNP)
#   over/IN
#   the/DT
#   cash-for-query/JJ
#   allegations/NNS
#   against/IN
#   her/PRP
#   ./.
#   (PERSON Moitra/NNP)
#   was/VBD
#   ousted/VBN
#   from/IN
#   the/DT
#   (ORGANIZATION Parliament/NNP)
#   last/JJ
#   week/NN
#   after/IN
#   the/DT
#   (ORGANIZATION Ethics/NNP Committee/NNP)
#   of/IN
#   the/DT
#   (ORGANIZATION Lok/NNP Sabha/NNP)
#   found/VBD
#   her/PRP$
#   guilty/JJ
#   of/IN
#   jeopardising/VBG
#   national/JJ
#   security/NN
#   by/IN
#   sharing/VBG
#   her/PRP$
#   parliamentary/JJ
#   portal/NN
#   's/POS
#   login/NN
#   credentials/NNS
#   with/IN
#   businessman/NN
#   (PERSON Darshan/NNP Hiranandani/NNP)
#   ./.)
