# %% [markdown]
# ### Lemmatization
#
# Lemmatization is an important text pre-processing technique in Natural Language Processing (NLP) that reduces words to their base form known as a "lemma."
#
#
# ##### wordnetlemmatizer parameters
# * pos -
# 1. noun - n
# 2. verb - v
# 3. adjective - a
# 4. adverb - r

# %%
### wordnetlemmaztizer

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["running", "jumps", "happily", "programming", "fairly"]

for word in words:
    print(word+"---->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# running---->run
# jumps---->jump
# happily---->happily
# programming---->program
# fairly---->fairly

# %% [markdown]
# lemmatization provides meaningful words
