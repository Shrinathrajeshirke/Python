# %% [markdown]
# ### One hot encoding
#
# #### Advantages:
# 1. Easy to implement with python -- sklearn onehotencode and pandas.get_dummies
#
# #### Disadvantages:
# 1. creates sparse matrix
# 2. for ML algo, we need fixed size inputs but one hot encode does not provides it
# 3. no semantic meaning captured
# 4. out of vocabulary -- testing word may not be present in training corpus (vocabulary)
